# %%
# %pylab inline
import seaborn as sns
sns.set_context('talk')
plt.rc("figure", figsize=(15,5))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = np.random.random(1000000)*2-1
hist(x,100); #semi-colon hide output

# %%
x += np.random.random(1000000)*2-1
hist(x,100);

# %%
for i in range(40):
    x += np.random.random(1000000)*2-1
hist(x,100);
